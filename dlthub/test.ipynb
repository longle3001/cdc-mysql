# %%
import dlt

data = [{"id": 1, "name": "Alice"}, {"id": 2, "name": "Bob"}]

pipeline = dlt.pipeline(
    pipeline_name="quick_start", destination="clickhouse", dataset_name="mydata"
)
load_info = pipeline.run(data, table_name="users")

print(load_info)
# Out:
# 2024-07-16 23:09:21,672|[WARNING]|69877|8009408192|dlt|pipeline.py|_state_to_props:1564|The destination dlt.destinations.duckdb:duckdb in state differs from destination dlt.destinations.clickhouse:clickhouse in pipeline and will be ignored
# ---------------------------------------------------------------------------
# ConfigFieldMissingException               Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/dlt/pipeline/pipeline.py:726, in Pipeline.sync_destination(self, destination, staging, dataset_name)
#     724 restored_schemas: Sequence[Schema] = None
# --> 726 remote_state = self._restore_state_from_destination()
#     728 # if remote state is newer or same
#     729 # print(f'REMOTE STATE: {(remote_state or {}).get("_state_version")} >= {state["_state_version"]}')
#     730 # TODO: check if remote_state["_state_version"] is not in 10 recent version. then we know remote is newer.
#
# ...
